# %% [markdown]
# This is the notebook builds a PDF the sample NeurIPS 2026 template notebook `neurips_2026.ipynb`.
#
# You could do all of this from within the NeurIPS 2026 notebook, I'm just keeping it separate for demo purposes.

# %%
from solveit_tex import export_ipynb_to_tex, compile_latex

# %%
# So that the LLM can use these
allow(export_ipynb_to_tex)
allow(compile_latex)
# Out:
# <function solveit_tex.compile_latex(tex_file: str, cwd: str = '.')>

# %%
export_ipynb_to_tex('neurips_2026.ipynb')
# Out:
# Created neurips_2026.tex

# %%
compile_latex('neurips_2026.tex')
# Out:
# Running pdflatex (pass 1)...
# Running bibtex (references)...
# Running pdflatex (pass 2)...
# Running pdflatex (pass 3)...
# Success!
# File: /app/data/solveit-tex/example/neurips_2026.pdf
# PDF url: https://serene-vision-dives-ildq3w.solve.it.com/static/solveit-tex/example/neurips_2026.pdf
# HTML(<a href="https://serene-vision-dives-ildq3w.solve.it.com/static/solveit-tex/example/neurips_2026.pdf" target="_blank">https://serene-vision-dives-ildq3w.solve.it.com/static/solveit-tex/example/neurips_2026.pdf</a>)
